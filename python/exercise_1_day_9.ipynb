# %%
import numpy as np
import pandas as pd
import seaborn as sns

# %%
#read in feature counts file
read_counts = pd.read_csv('2.2a_ex1_featurecounts.tsv',
                          sep="\t",
                          header=0,
                         comment='#')
read_counts.head()
# Out:
#     Geneid                                                Chr  \
# 0  DDX11L1                                     chr1;chr1;chr1
# 1   WASH7P  chr1;chr1;chr1;chr1;chr1;chr1;chr1;chr1;chr1;c...
# 2  FAM138A                   chr1;chr1;chr1;chr19;chr19;chr19
# 3  FAM138F                   chr1;chr1;chr1;chr19;chr19;chr19
# 4    OR4F5                                               chr1
#
#                                                Start  \
# 0                                  11874;12613;13221
# 1  14362;14970;15796;16607;16858;17233;17606;1791...
# 2                34611;35277;35721;76220;76886;77330
# 3                34611;35277;35721;76220;76886;77330
# 4                                              69091
#
#                                                  End                 Strand  \
# 0                                  12227;12721;14409                  +;+;+
# 1  14829;15038;15947;16765;17055;17368;17742;1806...  -;-;-;-;-;-;-;-;-;-;-
# 2                35174;35481;36081;76783;77090;77690            -;-;-;-;-;-
# 3                35174;35481;36081;76783;77090;77690            -;-;-;-;-;-
# 4                                              70008                      +
#
#    Length  bam/RS411-nasc-1.bam  bam/RS411-nasc-2.bam  bam/RS411-nasc-3.bam  \
# 0    1652                     9                     6                     8
# 1    1769                   132                    86                   105
# 2    2260                     0                     0                     0
# 3    2260                     0                     0                     0
# 4     918                     0                     0                     0
#
#    bam/SEM-nasc-1.bam  bam/SEM-nasc-2.bam  bam/SEM-nasc-3.bam
# 0                   8                   8                   6
# 1                  93                 102                 135
# 2                   0                   0                   0
# 3                   0                   0                   0
# 4                   0                   0                   0

# %%
#dropping columns Chr, Start, End, Strand and Length, axis 1 indicates columns
read_counts_df = read_counts.drop(['Chr', 'Start', 'End', 'Strand', 'Length'], axis=1)

# %%
read_counts_df
# Out:
#           Geneid  bam/RS411-nasc-1.bam  bam/RS411-nasc-2.bam  \
# 0        DDX11L1                     9                     6
# 1         WASH7P                   132                    86
# 2        FAM138A                     0                     0
# 3        FAM138F                     0                     0
# 4          OR4F5                     0                     0
# ...          ...                   ...                   ...
# 23705      CDY1B                     0                     0
# 23706       CDY1                     0                     0
# 23707   CSPG4P1Y                     0                     0
# 23708  GOLGA2P3Y                     0                     0
# 23709  GOLGA2P2Y                     0                     0
#
#        bam/RS411-nasc-3.bam  bam/SEM-nasc-1.bam  bam/SEM-nasc-2.bam  \
# 0                         8                   8                   8
# 1                       105                  93                 102
# 2                         0                   0                   0
# 3                         0                   0                   0
# 4                         0                   0                   0
# ...                     ...                 ...                 ...
# 23705                     0                   0                   0
# 23706                     0                   0                   0
# 23707                     0                   0                   0
# 23708                     0                   0                   0
# 23709                     0                   0                   0
#
#        bam/SEM-nasc-3.bam
# 0                       6
# 1                     135
# 2                       0
# 3                       0
# 4                       0
# ...                   ...
# 23705                   0
# 23706                   0
# 23707                   0
# 23708                   0
# 23709                   0
#
# [23710 rows x 7 columns]

# %%
#rename columns
read_counts_renamed = read_counts_df.rename(columns={"bam/RS411-nasc-1.bam":"RS411_rep1", "bam/RS411-nasc-2.bam":"RS411_rep2", "bam/RS411-nasc-3.bam":"RS411_rep3", "bam/SEM-nasc-1.bam":"SEM_rep1", "bam/SEM-nasc-2.bam":"SEM_rep2", "bam/SEM-nasc-3.bam":"SEM_rep3"})

# %%
read_counts_renamed
# Out:
#           Geneid  RS411_rep1  RS411_rep2  RS411_rep3  SEM_rep1  SEM_rep2  \
# 0        DDX11L1           9           6           8         8         8
# 1         WASH7P         132          86         105        93       102
# 2        FAM138A           0           0           0         0         0
# 3        FAM138F           0           0           0         0         0
# 4          OR4F5           0           0           0         0         0
# ...          ...         ...         ...         ...       ...       ...
# 23705      CDY1B           0           0           0         0         0
# 23706       CDY1           0           0           0         0         0
# 23707   CSPG4P1Y           0           0           0         0         0
# 23708  GOLGA2P3Y           0           0           0         0         0
# 23709  GOLGA2P2Y           0           0           0         0         0
#
#        SEM_rep3
# 0             6
# 1           135
# 2             0
# 3             0
# 4             0
# ...         ...
# 23705         0
# 23706         0
# 23707         0
# 23708         0
# 23709         0
#
# [23710 rows x 7 columns]

# %%
#filter out genes with no counts

read_counts_filtered = read_counts_renamed.query("RS411_rep1 > 0 & RS411_rep2 > 0 & RS411_rep3 > 0 & SEM_rep1 > 0 & SEM_rep2 > 0 & SEM_rep3 > 0")

# %%
read_counts_filtered
# Out:
#              Geneid  RS411_rep1  RS411_rep2  RS411_rep3  SEM_rep1  SEM_rep2  \
# 0           DDX11L1           9           6           8         8         8
# 1            WASH7P         132          86         105        93       102
# 8      LOC100133331          86          72          73        69        26
# 12     LOC100288069          58          46          52        36        55
# 13        LINC00115          69          74          86        69        75
# ...             ...         ...         ...         ...       ...       ...
# 23602     TMLHE-AS1           3           3           1         5         3
# 23604         TMLHE          84          56          57        78        93
# 23607          IL9R           4           1           1         8         2
# 23629          PRKY           4           3           4         1         1
# 23669          CD24        1399         953        1126        27        46
#
#        SEM_rep3
# 0             6
# 1           135
# 8            62
# 12           32
# 13           77
# ...         ...
# 23602         4
# 23604        86
# 23607         1
# 23629         1
# 23669        21
#
# [15061 rows x 7 columns]

# %%
#set gene id as the index so that it becomes an index rather than a column and isnt included in the scatterplot

read_counts_filtered.set_index("Geneid")
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Input In [19], in <cell line: 3>()
#       1 #set gene id as the index so that it becomes an index rather than a column and isnt included in the scatterplot
# ----> 3 read_counts_filtered.set_index("Geneid")
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/pandas/util/_decorators.py:311, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     305 if len(args) > num_allow_args:
#     306     warnings.warn(
#     307         msg.format(arguments=arguments),
#     308         FutureWarning,
#     309         stacklevel=stacklevel,
#     310     )
# --> 311 return func(*args, **kwargs)
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/frame.py:5494, in DataFrame.set_index(self, keys, drop, append, inplace, verify_integrity)
#    5491                 missing.append(col)
#    5493 if missing:
# -> 5494     raise KeyError(f"None of {missing} are in the columns")
#    5496 if inplace:
#    5497     frame = self
#
# KeyError: "None of ['Geneid'] are in the columns"

# %%
read_counts_filtered
# Out:
#               RS411_rep1  RS411_rep2  RS411_rep3  SEM_rep1  SEM_rep2  SEM_rep3
# Geneid
# DDX11L1                9           6           8         8         8         6
# WASH7P               132          86         105        93       102       135
# LOC100133331          86          72          73        69        26        62
# LOC100288069          58          46          52        36        55        32
# LINC00115             69          74          86        69        75        77
# ...                  ...         ...         ...       ...       ...       ...
# TMLHE-AS1              3           3           1         5         3         4
# TMLHE                 84          56          57        78        93        86
# IL9R                   4           1           1         8         2         1
# PRKY                   4           3           4         1         1         1
# CD24                1399         953        1126        27        46        21
#
# [15061 rows x 6 columns]

# %%
#generate a scatter plot of the filtered read counts
sns.pairplot(read_counts_filtered)

# %%
sns.pairplot(read_counts_filtered, diag_kind="hist")
